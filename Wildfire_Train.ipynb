# %%
import pprint
import rasterio
from rasterio import features
import rasterio.warp
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import zoom
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
from torch.utils.data import Dataset
from torch.optim.lr_scheduler import StepLR

# %%
# Base values
channel_descriptions = ['M11', 'I2', 'I1', 'NDVI_last', 'EVI2_last', 'total precipitation', 'wind speed', 'wind direction', 'minimum temperature', 'maximum temperature', 'energy release component', 'specific humidity', 'slope', 'aspect', 'elevation', 'pdsi', 'LC_Type1', 'total_precipitation_surface_last', 'forecast wind speed', 'forecast wind direction', 'forecast temperature', 'forecast specific humidity', 'active fire']

min_values = [np.float32(-100.0),
  np.float32(-100.0),
  np.float32(-100.0),
  np.float32(-9863.268),
  np.float32(-4422.217),
  np.float32(0.0),
  np.float32(0.0),
  np.float32(0.0),
  np.float32(0.0),
  np.float32(0.0),
  np.float32(0.0),
  np.float32(0.0),
  np.float32(0.0),
  np.float32(0.0),
  np.float32(-84.0),
  np.float32(-6.72),
  np.float32(1.0),
  np.float32(0.0),
  np.float32(0.0),
  np.float32(-89.999214),
  np.float32(-13.984883),
  np.float32(0.0),
  np.float32(0.0)]

max_values = [np.float32(15976.0),
  np.float32(15799.0),
  np.float32(15744.0),
  np.float32(9975.073),
  np.float32(9856.787),
  np.float32(122.0),
  np.float32(16.2),
  np.float32(360.0),
  np.float32(311.8),
  np.float32(325.4),
  np.float32(122.0),
  np.float32(0.01888),
  np.float32(63.85685),
  np.float32(359.42383),
  np.float32(4268.336),
  np.float32(8.28),
  np.float32(17.0),
  np.float32(204.1875),
  np.float32(14.295916),
  np.float32(89.98897),
  np.float32(39.505894),
  np.float32(0.0122514665),
  np.float32(2218.0)]

# %%
fire_folders = []
look_back = 5   # 5 days sequence
all_frames = []
data_limit, loop_counter, loop_start = 30, 0, 0
channel_descriptions = None
base_path = "./data"

target_shape_h, target_shape_w = 128, 128

print('Loading...')

for fire_folder in os.listdir(base_path):
    loop_counter += 1
    if loop_counter - loop_start > data_limit:
        break
    if loop_counter < loop_start:
        continue
    print('Progress: {0}/{1} ({2})'.format(loop_counter - loop_start, data_limit, loop_counter))
    fire_folders.append(fire_folder)
    for image_name in os.listdir(base_path + f"/{fire_folder}"):
        file_path = base_path + f"/{fire_folder}/{image_name}"
        
        with rasterio.open(file_path, 'r') as geotiff:
            src = geotiff.read()
            channel_descriptions = geotiff.descriptions
            zoom_factor = (1, target_shape_h / src.shape[1], target_shape_w / src.shape[2])
            resized_src = zoom(src, zoom_factor, order=1)
            resized_src = np.nan_to_num(resized_src, copy=True)
            all_frames.append(resized_src)

print(f'Loading done! Count = {len(all_frames)} | Shape = {all_frames[0].shape}')

data_frames = np.stack(all_frames)
print(data_frames.shape)
# Out:
# Loading...
# Progress: 1/30 (1)
# Progress: 2/30 (2)
# Progress: 3/30 (3)
# Progress: 4/30 (4)
# Progress: 5/30 (5)
# Progress: 6/30 (6)
# Progress: 7/30 (7)
# Progress: 8/30 (8)
# Progress: 9/30 (9)
# Progress: 10/30 (10)
# Progress: 11/30 (11)
# Progress: 12/30 (12)
# Progress: 13/30 (13)
# Progress: 14/30 (14)
# Progress: 15/30 (15)
# Progress: 16/30 (16)
# Progress: 17/30 (17)
# Progress: 18/30 (18)
# Progress: 19/30 (19)
# Progress: 20/30 (20)
# Progress: 21/30 (21)
# Progress: 22/30 (22)
# Progress: 23/30 (23)
# Progress: 24/30 (24)
# Progress: 25/30 (25)
# Progress: 26/30 (26)
# Progress: 27/30 (27)
# Progress: 28/30 (28)
# Progress: 29/30 (29)
# Progress: 30/30 (30)
# Loading done! Count = 726 | Shape = (23, 128, 128)
# (726, 23, 128, 128)

# %%
# Normalize each channel individually

for c in range(23):
    data_frames[:, c, :, :] = (data_frames[:, c, :, :] - min_values[c]) / (max_values[c] - min_values[c])

# %%
np.min(data_frames), np.max(data_frames)
# Out:
# (np.float32(0.0), np.float32(1.0))

# %%
np.min(data_frames[:, 22]), np.max(data_frames[:, 22])
# Out:
# (np.float32(0.0), np.float32(0.99729484))

# %%
X = []
Y = []

# Current shape of data_frames is (726, 23, H, W)
# look_back = 5

for t in range(0, data_frames.shape[0] - look_back):
    x_seq = data_frames[t:t+look_back]               # shape: (5, 23, H, W)
    y_mask = data_frames[t + look_back, 22]           # fire mask from channel 22

    X.append(x_seq)
    Y.append(y_mask)     # binarize

X = np.stack(X)  # shape: (721, 5, 23, 128, 128)
Y = np.expand_dims(np.stack(Y), axis=1)  # shape: (721, 1, 128, 128)

print(X.shape)
print(Y.shape)
# Out:
# (721, 5, 23, 128, 128)
# (721, 1, 128, 128)

# %%
split_index = int(X.shape[0] * 0.8)

X_train = X[:split_index]
X_val = X[split_index:]

Y_train = Y[:split_index]
Y_val = Y[split_index:]

X_train.shape, Y_train.shape, X_val.shape, Y_val.shape
# Out:
# ((576, 5, 23, 128, 128),
#  (576, 1, 128, 128),
#  (145, 5, 23, 128, 128),
#  (145, 1, 128, 128))

# %%
X_train = torch.tensor(X_train).float()
Y_train = torch.tensor(Y_train).float()

X_val = torch.tensor(X_val).float()
Y_val = torch.tensor(Y_val).float()

X_train.shape, Y_train.shape, X_val.shape, Y_val.shape
# Out:
# (torch.Size([576, 5, 23, 128, 128]),
#  torch.Size([576, 1, 128, 128]),
#  torch.Size([145, 5, 23, 128, 128]),
#  torch.Size([145, 1, 128, 128]))

# %%
class WildfireDataset(Dataset):
    def __init__(self, X, Y):
        self.X = X
        self.Y = Y
    
    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.Y[i]

train_dataset = WildfireDataset(X_train, Y_train)
val_dataset = WildfireDataset(X_val, Y_val)

len(train_dataset), len(val_dataset)
# Out:
# (576, 145)

# %%
from torch.utils.data import DataLoader

batch_size = 8

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

device
# Out:
# device(type='cuda')

# %%
import convlstm

class Net(nn.Module):
    def __init__(self):
        super().__init__()
        orig_size = (330, 257)

        self.clstm = convlstm.ConvLSTM(
            input_size=(128, 128),
            input_dim=23,
            hidden_dim=[64],
            kernel_size=(3, 3),
            num_layers=1
        )
        # (8, 64, 128, 128)
        
        self.head = nn.Sequential(
            nn.Conv2d(64, 1, kernel_size=3, padding=1),
            nn.Sigmoid()
        )
        # (8, 1, 128, 128)

    def forward(self, x):
        batch_size = x.size(0)
        outputs, last_states = self.clstm(x)

        x = outputs[0][:, -1, :, :, :]
        x = self.head(x)
        return x

model = Net().to(device)

# %%
class DiceLoss(nn.Module):
    def __init__(self, smooth=1.0):
        super().__init__()
        self.smooth = smooth

    def forward(self, y_pred, y_true):
        # (8, 1, 128, 128)

        y_pred_flat = y_pred.view(y_pred.size(0), -1) # (8, 16384)
        y_true_flat = y_true.view(y_true.size(0), -1) # (8, 16384)

        intersection = (y_pred_flat * y_true_flat).sum(dim=1)
        union = y_pred_flat.sum(dim=1) + y_true_flat.sum(dim=1)

        dice_score = (2 * intersection + self.smooth) / (union + self.smooth)
        dice_loss = 1 - dice_score.mean()
        
        return dice_loss


class WeightedDiceLoss(nn.Module):
    def __init__(self, pos_weight=20.0, smooth=1.0):
        super(WeightedDiceLoss, self).__init__()
        self.pos_weight = pos_weight
        self.smooth = smooth

    def forward(self, y_pred, y_true):
        """
        y_pred: Tensor of shape (B, 1, H, W), after sigmoid
        y_true: Tensor of shape (B, 1, H, W), binary (0 or 1)
        pos_weight: scalar value to boost the importance of foreground (y_true == 1)
        """

        y_pred = y_pred.contiguous()
        y_true = y_true.contiguous()

        # Flatten the predictions and targets
        y_pred_flat = y_pred.view(y_pred.size(0), -1)
        y_true_flat = y_true.view(y_true.size(0), -1)

        # Create weight tensor: 1 for background, pos_weight for foreground
        weights = torch.ones_like(y_true_flat)
        weights[y_true_flat == 1] = self.pos_weight

        # Apply weights to both prediction and ground truth
        intersection = (weights * y_pred_flat * y_true_flat).sum(dim=1)
        union = (weights * y_pred_flat).sum(dim=1) + (weights * y_true_flat).sum(dim=1)

        dice_score = (2.0 * intersection + self.smooth) / (union + self.smooth)
        dice_loss = 1.0 - dice_score

        return dice_loss.mean()

class WeightedJaccardLoss(nn.Module):
    def __init__(self, pos_weight=50.0, smooth=1e-6):
        super(WeightedJaccardLoss, self).__init__()
        self.pos_weight = pos_weight
        self.smooth = smooth

    def forward(self, y_pred, y_true):
        """
        y_pred: Tensor of shape (B, 1, H, W), after sigmoid
        y_true: Tensor of shape (B, 1, H, W), binary (0 or 1)
        pos_weight: scalar that increases the importance of foreground (1s in y_true)
        """

        y_pred = y_pred.contiguous().view(y_pred.size(0), -1)
        y_true = y_true.contiguous().view(y_true.size(0), -1)

        # Create weights: pos_weight for foreground (1), 1.0 for background (0)
        weights = torch.ones_like(y_true)
        weights[y_true == 1] = self.pos_weight

        # Weighted intersection and union
        intersection = (weights * y_pred * y_true).sum(dim=1)
        union = (weights * (y_pred + y_true - y_pred * y_true)).sum(dim=1)

        jaccard_score = (intersection + self.smooth) / (union + self.smooth)
        jaccard_loss = 1.0 - jaccard_score

        return jaccard_loss.mean()


class BCEWeightedLoss(nn.Module):
    def __init__(self, eps=1e-7):
        super(BCEWeightedLoss, self).__init__()
        self.eps = eps  # to avoid log(0)
        self.pos_weight = 10.0
        self.neg_weight = 1.0
        self.dice = DiceLoss()

    def forward(self, y_pred, y_true):
        """
        y_pred: probabilities after sigmoid, shape (B, 1, H, W)
        y_true: binary targets, shape (B, 1, H, W)
        """
        # Clamp predictions to avoid log(0)
        y_pred = torch.clamp(y_pred, self.eps, 1.0 - self.eps)

        # BCE loss calculation
        loss = -(self.pos_weight * y_true * torch.log(y_pred) + self.neg_weight * (1 - y_true) * torch.log(1 - y_pred))

        return loss.mean()  # return scalar loss

# %%
lr = 0.01
num_epochs = 150

loss_fn = BCEWeightedLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=lr)
print_batch_every = 8

def train(epoch):
    model.train(True)
    print(f"Epoch: {epoch + 1}")
    running_loss = 0.0
    
    for batch_index, batch in enumerate(train_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)
        y_pred = model(x_batch)

        loss = loss_fn(y_pred, y_batch)
        running_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch_index % print_batch_every == (print_batch_every - 1):
            avg_loss_across_batches = running_loss / print_batch_every
            print('Batch {0}, Loss: {1:.3f}'.format(batch_index + 1, avg_loss_across_batches))
            running_loss = 0.0
    
    print()

def validate():
    model.train(False)
    running_loss = 0.0

    for batch_index, batch in enumerate(val_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        with torch.no_grad():
            y_pred = model(x_batch)
            loss = loss_fn(y_pred, y_batch)
            running_loss += loss.item()

    avg_loss_across_batches = running_loss / len(val_loader)
    print('Val Loss: {0:.3f}'.format(avg_loss_across_batches))
    print('**********************************************************')
    print()


for epoch in range(num_epochs):
    train(epoch)
    validate()
# Out:
# Epoch: 1
# C:\Users\neelr\AppData\Local\Temp\ipykernel_32236\1989858788.py:20: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\Scalar.cpp:23.)
#   running_loss += loss.item()
# Batch 8, Loss: 0.777
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 2
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 3
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 4
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 5
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 6
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 7
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 8
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 9
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 10
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 11
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 12
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 13
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 14
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 15
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 16
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 17
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 18
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 19
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 20
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 21
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 22
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 23
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 24
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 25
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 26
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 27
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 28
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 29
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 30
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 31
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 32
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 33
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 34
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 35
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 36
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 37
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 38
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 39
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 40
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 41
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 42
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 43
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 44
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 45
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 46
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 47
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 48
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 49
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 50
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 51
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 52
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 53
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 54
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 55
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 56
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 57
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 58
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 59
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 60
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 61
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 62
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 63
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 64
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 65
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 66
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 67
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 68
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 69
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 70
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 71
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 72
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 73
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 74
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 75
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 76
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 77
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 78
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 79
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 80
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 81
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 82
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 83
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 84
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 85
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 86
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 87
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 88
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 89
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 90
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 91
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 92
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 93
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 94
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 95
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 96
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 97
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 98
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 99
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************
#
# Epoch: 100
# Batch 8, Loss: 0.355
# Batch 16, Loss: 0.512
# Batch 24, Loss: 0.398
# Batch 32, Loss: 0.525
# Batch 40, Loss: 0.184
# Batch 48, Loss: 0.124
# Batch 56, Loss: 0.583
# Batch 64, Loss: 0.709
# Batch 72, Loss: 0.794
#
# Val Loss: 0.494
# **********************************************************

# %%
for batch_index, batch in enumerate(train_loader):
    if batch_index == 4:
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)
        y_pred = model(x_batch)
        print("found")
        break
# Out:
# found

# %%
torch.max(y_batch), torch.max(y_pred), torch.min(y_batch), torch.min(y_pred)
# Out:
# (tensor(0.9495, device='cuda:0'),
#  tensor(1.6549e-10, device='cuda:0', grad_fn=<MaxBackward1>),
#  tensor(0., device='cuda:0'),
#  tensor(2.3976e-22, device='cuda:0', grad_fn=<MinBackward1>))

# %%
y_batch_np = y_batch.cpu().detach().numpy()
y_pred_np = y_pred.cpu().detach().numpy()

y_pred_avg = (np.min(y_pred_np) + np.max(y_pred_np)) / 2.0
#y_pred_np = (y_pred_np - 0.0) / (0.65 - 0.0)

y_batch_np.shape, y_pred_np.shape
# Out:
# ((8, 1, 128, 128), (8, 1, 128, 128))

# %%
np.max(y_pred_np), np.min(y_pred_np), y_pred_avg
# Out:
# (np.float32(1.6549194e-10),
#  np.float32(2.3975952e-22),
#  np.float32(8.274597e-11))

# %%
# Some visualizations

for i in range(y_batch_np.shape[0]):
    plt.figure()
    plt.title(f"Actual {i + 1}")
    split_val = 0.15
    val = y_batch_np[i, 0]
    plt.imshow(np.piecewise(val, [val < split_val, val >= split_val], [0, 1]))

    plt.figure()
    plt.title(f"Predicted {i + 1}")
    split_val = 0.5
    val = y_pred_np[i, 0]
    plt.imshow(np.piecewise(val, [val < split_val, val >= split_val], [0, 1]))
    #plt.imshow(val)

# %%
for batch_index, batch in enumerate(val_loader):
    if batch_index == 2:
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)
        y_pred = model(x_batch)
        print("found")
        break

print(torch.max(y_batch), torch.max(y_pred), torch.min(y_batch), torch.min(y_pred))

y_batch_np = y_batch.cpu().detach().numpy()
y_pred_np = y_pred.cpu().detach().numpy()
# Out:
# found
# tensor(0.9576, device='cuda:0') tensor(1.6530e-10, device='cuda:0', grad_fn=<MaxBackward1>) tensor(0., device='cuda:0') tensor(2.3787e-22, device='cuda:0', grad_fn=<MinBackward1>)

# %%
for i in range(y_batch_np.shape[0]):
    plt.figure()
    plt.title(f"Actual {i + 1}")
    split_val = 0.15
    val = y_batch_np[i, 0]
    plt.imshow(np.piecewise(val, [val < split_val, val >= split_val], [0, 1]))
    #plt.imshow(y_batch_np[i, 0])

    plt.figure()
    plt.title(f"Predicted {i + 1}")
    split_val = 0.5
    val = y_pred_np[i, 0]
    plt.imshow(np.piecewise(val, [val < split_val, val >= split_val], [0, 1]))
    #plt.imshow(y_pred_np[i, 0])

# %%
from sklearn.metrics import precision_score

# %%
tolerance = 0.01
accuracy = 0
precision = 0
accuracy_counter = 0
precision_counter = 0
show_figures = False

for batch_index, batch in enumerate(val_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    y_pred = model(x_batch)

    y_batch_np = y_batch.cpu().detach().numpy()
    y_pred_np = y_pred.cpu().detach().numpy()

    for i in range(y_batch_np.shape[0]): # Each image in a batch = batch_size
        split_val = 0.15
        value_true = y_batch_np[i, 0]
        value_true = np.piecewise(value_true, [value_true < split_val, value_true >= split_val], [0, 1])
        if show_figures:
            plt.figure()
            plt.title("Actual")
            plt.imshow(value_true)

        split_val = 0.5
        value_pred = y_pred_np[i, 0]
        value_pred = np.piecewise(value_pred, [value_pred < split_val, value_pred >= split_val], [0, 1])
        if show_figures:
            plt.figure()
            plt.title("Predicted")
            plt.imshow(value_pred)

        correct = np.abs(value_pred - value_true) <= tolerance
        
        accuracy += correct.sum() / correct.size
        accuracy_counter += 1

        TP = np.logical_and(value_pred == 1, value_true == 1).sum()
        FP = np.logical_and(value_pred == 1, value_true == 0).sum()
        
        precision += TP / (TP + FP + 1e-7)  # Add small epsilon to avoid division by zero
        precision_counter += 1
        
avg_accuracy = accuracy / accuracy_counter
avg_precision = precision / precision_counter

print(f"Accuracy: {np.floor(avg_accuracy * 100):.0f}%; Precision: {avg_precision}")
# Out:
# Accuracy: 99%; Precision: 0.0

# %%
torch.save(model.state_dict(), 'model-weights.pth')
